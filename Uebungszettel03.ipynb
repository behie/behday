# %% [markdown]
# ## Übungszettel 3: Korrelationen
#
# ## Maschinelles Lernen - WiSe 20/21
#
# ### Abgabe 27.11.2020, 12 Uhr
#
# Übungsaufgaben **müssen** in Gruppen von 3-4 Personen abgegeben werden. **Einzelabgaben werden nicht korrigiert bzw. bewertet**. Alle Lösungen sollen in _einem_ IPython Notebook realisiert werden, wobei Teilaufgaben und Zwischenergebnisse ausgegeben bzw. visualisiert werden sollen.
# Das IPython Notebook und ggf. zugehörige Dateien müssen in ein Ziparchiv gepackt werden und in Ilias hochgeladen werden. Das Ziparchiv soll nach folgendem Muster benannt werden:
# `UebungXX_Nachname1_Nachname2_Nachname3.zip`, wobei die Nachnamen in alphabetischer Reihenfolge angegeben werden und Umlaute ggf. ersetzt werden.
#
# <span style="color: #e10000;
# font-face: 27;
# font-size: 17px;
# font-weight: 600;">Bitte beachten Sie, dass die Übungen ab dieser Woche bereits bis Freitag, 12 Uhr abgegeben werden müssen!</span>

# %% [markdown]
# ### Aufgabe 1 - Pearson-Korrelation und Rangkorrelationskoeffizient
#
# Sie können in den folgenden Aufgaben die Libraries `numpy`, `matplotlib`, `pandas` nutzen.

# %% [markdown]
# #### Aufgabe 1.1: Daten einlesen und plotten (1+1,5+1+2,5 Punkte)
#
#
# * Lesen Sie die Datei https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv ein
# * Erstellen Sie jeweils ein Balkendiagramm für die Variablen `year` (x-Achse) und `co2` (Höhe der Balken) für folgende Werte der Spalte `country`:
#     * `Germany`
#     * `United States`
#     * ein weiteres Land
# * Berechnen Sie die Werte für die Pro-Kopf Emissionen, indem sie die Werte der Spalte `co2` durch die der Spalte `population` teilen
# * Erstellen Sie einen weiteren Plot, auf dem die Balkendiagramme ab dem Jahr 1990 (`year >= 1990`) für diese Länder gruppiert dargestellt werden. Außerdem sollen nun statt den Gesamtemissionen die Emissionen pro Kopf dargestellt werden. *Tipp:* Nutzen Sie hier die Library `seaborn`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

table = pd.read_csv("https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv")
#print(table.head())

table_germany = table[table["country"]=="Germany"]
plt.bar(table_germany['year'], table_germany['co2'], color = "black")
plt.title('GERMANY co2 emission')
plt.xlabel('year')
plt.ylabel('co2 emission')
plt.show()

table_usa = table[table["country"]=="North America"]
plt.bar(table_usa['year'], table_usa['co2'], color = "blue")
plt.title('USA co2 emission')
plt.xlabel('year')
plt.ylabel('co2 emission')
plt.show()

table_iran = table[table["country"]=="Iran"]
plt.bar(table_iran['year'], table_iran['co2'], color = "green")
plt.title('IRAN co2 emission')
plt.xlabel('year')
plt.ylabel('co2 emission')
plt.show()

###########################################################

print("Teil 2:\n Emission pro person")

df = pd.read_csv('https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv')
df_emi = np.divide(df['co2'], df['population'])
df['emi'] = df_emi

print(df_emi)

#############################################################

print("\n\nTeil 3:\n ab 1990")

df_g = df[df["country"] == "Germany"]
df_g_90 = df_g[df_g["year"]>=1990]
emi = np.divide(df_g_90['co2'], df_g_90['population'])
sns.barplot(x='year', y='emi', data=df_g_90)
plt.title('Germany co2 emission pro person')
plt.xlabel('year')
plt.ylabel('co2 emission')
plt.show()


df_g = df[df["country"] == "North America"]
df_g_90 = df_g[df_g["year"]>=1990]
emi = np.divide(df_g_90['co2'], df_g_90['population'])
sns.barplot(x='year', y='emi', data=df_g_90)
plt.title('USA co2 emission pro person')
plt.xlabel('year')
plt.ylabel('co2 emission')
plt.show()


df_g = df[df["country"] == "Iran"]
df_g_90 = df_g[df_g["year"]>=1990]
emi = np.divide(df_g_90['co2'], df_g_90['population'])
sns.barplot(x='year', y='emi', data=df_g_90)
plt.title('IRAN co2 emission pro person')
plt.xlabel('year')
plt.ylabel('co2 emission')
plt.show()
# Out:
# Teil 2:
#  Emission pro person
# 0        1.957258e-09
# 1        1.083591e-08
# 2        1.173469e-08
# 3        1.159274e-08
# 4        1.318408e-08
#              ...
# 24011    8.804004e-07
# 24012    8.804198e-07
# 24013    7.702780e-07
# 24014    8.447004e-07
# 24015    8.492970e-07
# Length: 24016, dtype: float64
#
#
# Teil 3:
#  ab 1990

# %% [markdown]
# #### Aufgabe 1.2: Pearson-Korrelation (0,5+2+1+0,5 Punkte)
#
# a) Wählen Sie die Merkmale `co2` und `year` für `country=Germany` und `year > 2013` aus.

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv')
dfg = df[df["country"] == "Germany"]
dfg2013 = dfg[dfg["year"]>=2013]
dfg2013.reset_index(inplace=True)
dfg2013[['year','co2']]
# Out:
# -0.4857142857142857

# %% [markdown]
# b) Berechnen Sie die Pearson-Korrelation von Hand für die zwei Merkmale aus a). Für die Darstellung des Rechenweges können Sie LaTex in Markdown benutzen.
# Beispiel für das Einbinden einer Latex-Formel:
# $$ \bar{x} = \frac{1}{n} \sum ^n _{i=1} x_i $$
# Alternativ können Sie auch ein Foto des Rechenweges einbinden.

# %% [markdown]
# $$ \text{Hier können Sie Ihre Lösung in } \mathrm{L\!\!^{{}_{A}} \!\!\!\!\!\;\; T\!_{\displaystyle E} \! X} \text{ einfügen...} $$
#
# ![Bild](https://via.placeholder.com/500x80?text=...oder+ein+Bild+einbinden.)

# %% [markdown]
# c) Schreiben Sie eine Funktion welche die Pearson-Korrelation zwischen zwei Merkmalen berechnet. In
# dieser Teilaufgabe dürfen Sie keine Pakete und insbesondere kein Numpy verwenden.

# %%
import math
def pearson(x,y):
    x_m = (sum(x)/len(x))
    y_m = (sum(y)/len(y))

    s1 = 0.0
    s2 = 0.0
    s3 = 0.0

    for i in range (len(x)):
        s1 += (x[i]-x_m)*(y[i]-y_m)
        s2 += (x[i]-x_m)*(x[i]-x_m)
        s3 += (y[i]-y_m)*(y[i]-y_m)

    s4 = math.sqrt(s2*s3)

    r = s1/s4
    return(r)

# %% [markdown]
# d) Berechnen Sie mit der Funktion aus c) die Pearson-Korrelation für die Spalten `year` und `co2`, jeweils für `country=World` und `country=Germany`.

# %%
import pandas as pd
import math

def pearson(x,y):
    
    x_m = float(sum(x))/len(x)
    y_m = float(sum(y))/len(y)

    s1 = 0.0
    s2 = 0.0
    s3 = 0.0

    for i in range (len(x)):
        s1 += (x[i]-x_m)*(y[i]-y_m)
        s2 += (x[i]-x_m)*(x[i]-x_m)
        s3 += (y[i]-y_m)*(y[i]-y_m)

    s4 = math.sqrt(s2*s3)

    r = s1/s4
    return(r)


df = pd.read_csv('https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv')

dfg = df[df["country"] == "Germany"]
a = dfg["year"].tolist()
b = dfg["co2"].tolist()
print ("Germany:",pearson(a,b))

dfw = df[df["country"] == "World"]
c = dfw["year"].tolist()
d = dfw["co2"].tolist()
print ("\nWorld:", pearson(c,d))
# Out:
# Germany: 0.9302436052758248
#
# World: 0.7966999575087338

# %% [markdown]
# #### Aufgabe 1.3: Rang-Korrelationskoeffizient (3+1,5+0,5 Punkte)
#
# a) Nutzen Sie die Werte aus 1.2 a) und berechnen Sie den Rangkorrelationskoeffizienten von Hand. Für die Darstellung des Rechenweges können Sie LaTex in Markdown benutzen. Alternativ können Sie auch ein Foto des Rechenweges einbinden.

# %% [markdown]
# $$ \text{Hier können Sie Ihre Lösung in } \mathrm{L\!\!^{{}_{A}} \!\!\!\!\!\;\; T\!_{\displaystyle E} \! X} \text{ einfügen...} $$
#
# ![Bild](https://via.placeholder.com/500x80?text=...oder+ein+Bild+einbinden.)

# %% [markdown]
# b) Schreiben Sie eine Funktion welche den Rangkorrelationskoeffizienten zwischen zwei Merkmalen berechnet. In
# dieser Teilaufgabe dürfen Sie keine Pakete und insbesondere kein Numpy verwenden.

# %%
import math

def find_index(x):
    tempx1 = x.copy()
    ind = []
    for i in x:
        ind.append(x.index(min(tempx1)))
        tempx1.remove(min(tempx1))
    return ind

def rang(x):
    count = 1
    sort = []
    rang = []
    tempx = x.copy()
    while count <= len(x):
        sort.append(min(tempx))
        rang.append(count)
        tempx.remove(min(tempx))
        count += 1

    d = list(zip(sort,rang,find_index(x)))
    d.sort(key=lambda tup: tup[2])
    return d

def ave(x):
    d = rang(x)
    output = [x1[1] for x1 in d]
    return sum(output)/len(output)

def select(x,i):
    d = rang(x)
    output = [x1[i] for x1 in d]
    return output

def spearman(x,y):
    
    summx = select(x,1)
    summy = select(y,1)
    
    s = []
    t = []
    rez = []

    for ir in range(len(summx)):
        s.append((summx[ir]-ave(x))*(summy[ir]-ave(y)))
        summ1 = sum(s)

    for i in range(len(summx)):
        t.append((summx[i]-ave(x))**2)
        t2 = sum(t)
        t1 = math.sqrt(t2)
        rez.append((summy[i]-ave(y))**2)
        rez2 = sum(rez)
        rez1 = math.sqrt(rez2)

    final = (summ1/(t1*rez1))

    print(final)

    

# spearman([174,183,162,170,182,176,173,198],[73,93,74,58,90,88,72,91])

# %% [markdown]
# c) Berechnen Sie mit der Funktion aus b) den Rangkorrelationskoeffizienten für die Spalten `population` und `co2` mit `year >= 1800`, jeweils für `country=World` und `country=Germany`.

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv')
dfg = df[df["country"] == "Germany"]
dfg1800 = dfg[dfg["year"]>=1800]
# dfg2013.reset_index(inplace=True)
dfg1800[['population','co2']]
a = dfg1800['population'].tolist()
b = dfg1800['co2'].tolist()

spearman(a,b)
# Out:
# 0.9628000502702022
